# %% [markdown]
# # Plate QC
#
# Quality control & corrections of the cardiac differentiation plate

# %%
import ngio
from ngio.utils import fractal_fsspec_store
import pandas as pd
from aiohttp import ServerDisconnectedError

# %%
plate_url = "url/to/20200812-CardiomyocyteDifferentiation14-Cycle1_mip.zarr"
token = ""
plate_store = fractal_fsspec_store(url=plate_url, fractal_token=token)

# %%
plate = ngio.open_ome_zarr_plate(plate_store, parallel_safe=False)

# %%
plate.list_image_tables(mode="all")
# Out:
# ['FOV_ROI_table',
#  'well_ROI_table',
#  'nuclei_measurements_apx',
#  'nuclei_ROI_table',
#  'nuclei_measurements_scmultiplex',
#  'nuclei_measurements_apx_aggregated']

# %%
plate.list_tables()
# Out:
# ['registration_errors', 'differentiation_timepoints']

# %%
registration_errors_table = plate.get_table('registration_errors').dataframe
differentiation_timepoints_table = plate.get_table('differentiation_timepoints').dataframe
lookup = differentiation_timepoints_table[["well", "day"]].rename(
    columns={"day": "differentiation_day"}
)

# %%
differentiation_timepoints_table
# Out:
#    well  day row  column
# 0   B03    0   B       3
# 1   B05    6   B       5
# 2   B09    5   B       9
# 3   B11    0   B      11
# 4   C04    1   C       4
# 5   C06    9   C       6
# 6   C08    2   C       8
# 7   C10    8   C      10
# 8   D05    7   D       5
# 9   D09    4   D       9
# 10  D11   10   D      11
# 11  E04    4   E       4
# 12  E06   10   E       6
# 13  E08    1   E       8
# 14  E10    7   E      10
# 15  F03    2   F       3
# 16  F05    8   F       5
# 17  F09    3   F       9
# 18  F11    9   F      11
# 19  G04    5   G       4
# 20  G06    0   G       6
# 21  G08    0   G       8
# 22  G10    6   G      10

# %%
# Load the feature tables into memory as pandas DataFrames
# Loop over all acquisition 0 images, load their feature tables, and concatenate them
reference_acquisitions = plate.images_paths(acquisition=0)

# %%
# Debugging: Just process one well
# reference_acquisitions = ['B/05/0']

# %%
counter_qc = 0
counter_registration = 0
counter_segmentation = 0
concatenated_df = pd.DataFrame()

# %%
def load_qced_feature_table_for_well(plate, img_path, registration_errors_table, counter_qc, counter_registration, counter_segmentation):
    img = plate.get_image(row=img_path.split('/')[0], column=img_path.split('/')[1], image_path=img_path.split('/')[2])
    feature_table = img.get_table('nuclei_measurements_apx_aggregated')
    df = feature_table.dataframe.reset_index()
    
    # Kick out FOVs that occur in the registration_errors_table
    curr_well = df["well_name"][0]
    if curr_well in registration_errors_table["well"].values:
        misregistered_fovs = registration_errors_table[registration_errors_table["well"] == curr_well]
        for fov in misregistered_fovs["FOV"]:
            n = len(df[df["ROI"] == fov])
            print(
                f"Removing {fov} from well {curr_well} due to "
                f"registration errors. This removes {n} cells."
            )
            counter_qc += n
            counter_registration += n
            df = df[df["ROI"] != fov]
    
    # Kick out missegmented cells
    n_missegmented = sum(df["segmentation_qc"] != "Regular cells")
    print(
        f"Removing missegmented cells from {curr_well}: "
        f"This removes {n_missegmented} cells."
    )
    counter_qc += n_missegmented
    counter_segmentation += n_missegmented
    df = df[df["segmentation_qc"] == "Regular cells"]
    print(f"Loaded {len(df)} cells after QC from well {curr_well}.")
    return df, counter_qc, counter_registration, counter_segmentation

# %%
remaining_acquisitions = reference_acquisitions.copy()

# %%
to_be_processed_acquisitions = remaining_acquisitions.copy()
to_be_processed_acquisitions
# Out:
# ['B/09/0',
#  'C/08/0',
#  'C/10/0',
#  'D/11/0',
#  'E/04/0',
#  'E/08/0',
#  'F/03/0',
#  'F/09/0',
#  'C/04/0',
#  'D/05/0',
#  'D/09/0',
#  'E/06/0',
#  'E/10/0',
#  'F/05/0',
#  'B/03/0',
#  'B/05/0',
#  'B/11/0',
#  'C/06/0',
#  'F/11/0',
#  'G/04/0',
#  'G/06/0',
#  'G/08/0',
#  'G/10/0']

# %%
for img_path in to_be_processed_acquisitions:
    try:
        df, counter_qc, counter_registration, counter_segmentation = load_qced_feature_table_for_well(plate, img_path, registration_errors_table, counter_qc, counter_registration, counter_segmentation)
        print(f"Done processing well {img_path}")
        concatenated_df = pd.concat([concatenated_df, df])
        remaining_acquisitions.remove(img_path)
        print(f"Done concatenating data for well {img_path}")
    except ServerDisconnectedError:
        print(f"ServerDisconnectedError encountered while processing well {img_path}. Retrying later.")
    

print(f"Total number of removed cells during QC: {counter_qc}")
print(
    f" - of which {counter_registration} due to registration errors, "
    f"and {counter_segmentation} due to missegmentation."
)
# Out:
# Removing FOV_26 from well B09 due to registration errors. This removes 1439 cells.
# Removing FOV_39 from well B09 due to registration errors. This removes 602 cells.
# Removing FOV_40 from well B09 due to registration errors. This removes 204 cells.
# Removing FOV_47 from well B09 due to registration errors. This removes 881 cells.
# Removing FOV_48 from well B09 due to registration errors. This removes 1091 cells.
# Removing FOV_53 from well B09 due to registration errors. This removes 344 cells.
# Removing FOV_54 from well B09 due to registration errors. This removes 870 cells.
# Removing FOV_55 from well B09 due to registration errors. This removes 1274 cells.
# Removing FOV_56 from well B09 due to registration errors. This removes 470 cells.
# Removing FOV_61 from well B09 due to registration errors. This removes 257 cells.
# Removing FOV_62 from well B09 due to registration errors. This removes 695 cells.
# Removing FOV_63 from well B09 due to registration errors. This removes 835 cells.
# Removing FOV_64 from well B09 due to registration errors. This removes 19 cells.
# Removing FOV_68 from well B09 due to registration errors. This removes 559 cells.
# Removing FOV_69 from well B09 due to registration errors. This removes 24 cells.
# Removing FOV_70 from well B09 due to registration errors. This removes 836 cells.
# Removing FOV_71 from well B09 due to registration errors. This removes 652 cells.
# Removing FOV_72 from well B09 due to registration errors. This removes 0 cells.
# Removing missegmented cells from B09: This removes 3318 cells.
# Loaded 29041 cells after QC from well B09.
# Done processing well B/09/0
# Done concatenating data for well B/09/0
# Removing FOV_72 from well C08 due to registration errors. This removes 45 cells.
# Removing missegmented cells from C08: This removes 3673 cells.
# Loaded 21617 cells after QC from well C08.
# Done processing well C/08/0
# Done concatenating data for well C/08/0
# Removing missegmented cells from C10: This removes 17187 cells.
# Loaded 55755 cells after QC from well C10.
# Done processing well C/10/0
# Done concatenating data for well C/10/0
# Removing missegmented cells from D11: This removes 9966 cells.
# Loaded 50564 cells after QC from well D11.
# Done processing well D/11/0
# Done concatenating data for well D/11/0
# Removing FOV_72 from well E04 due to registration errors. This removes 249 cells.
# Removing missegmented cells from E04: This removes 3385 cells.
# Loaded 37589 cells after QC from well E04.
# Done processing well E/04/0
# Done concatenating data for well E/04/0
# Removing FOV_20 from well E08 due to registration errors. This removes 41 cells.
# Removing FOV_67 from well E08 due to registration errors. This removes 21 cells.
# Removing missegmented cells from E08: This removes 2326 cells.
# Loaded 29093 cells after QC from well E08.
# Done processing well E/08/0
# Done concatenating data for well E/08/0
# Removing missegmented cells from F03: This removes 3859 cells.
# Loaded 35464 cells after QC from well F03.
# Done processing well F/03/0
# Done concatenating data for well F/03/0
# Removing missegmented cells from F09: This removes 3245 cells.
# Loaded 35287 cells after QC from well F09.
# Done processing well F/09/0
# Done concatenating data for well F/09/0
# Removing missegmented cells from C04: This removes 4362 cells.
# Loaded 36369 cells after QC from well C04.
# Done processing well C/04/0
# Done concatenating data for well C/04/0
# Removing missegmented cells from D05: This removes 10395 cells.
# Loaded 59823 cells after QC from well D05.
# Done processing well D/05/0
# Done concatenating data for well D/05/0
# Removing FOV_68 from well D09 due to registration errors. This removes 874 cells.
# Removing FOV_69 from well D09 due to registration errors. This removes 694 cells.
# Removing missegmented cells from D09: This removes 3836 cells.
# Loaded 42261 cells after QC from well D09.
# Done processing well D/09/0
# Done concatenating data for well D/09/0
# Removing missegmented cells from E06: This removes 13517 cells.
# Loaded 49509 cells after QC from well E06.
# Done processing well E/06/0
# Done concatenating data for well E/06/0
# Removing missegmented cells from E10: This removes 9858 cells.
# Loaded 66919 cells after QC from well E10.
# Done processing well E/10/0
# Done concatenating data for well E/10/0
# Removing missegmented cells from F05: This removes 13963 cells.
# Loaded 63654 cells after QC from well F05.
# Done processing well F/05/0
# Done concatenating data for well F/05/0
# Removing missegmented cells from B03: This removes 1870 cells.
# Loaded 39460 cells after QC from well B03.
# Done processing well B/03/0
# Done concatenating data for well B/03/0
# Removing FOV_7 from well B05 due to registration errors. This removes 1271 cells.
# Removing FOV_8 from well B05 due to registration errors. This removes 1196 cells.
# Removing FOV_16 from well B05 due to registration errors. This removes 1219 cells.
# Removing missegmented cells from B05: This removes 7689 cells.
# Loaded 49589 cells after QC from well B05.
# Done processing well B/05/0
# Done concatenating data for well B/05/0
# Removing missegmented cells from B11: This removes 1622 cells.
# Loaded 34565 cells after QC from well B11.
# Done processing well B/11/0
# Done concatenating data for well B/11/0
# Removing missegmented cells from C06: This removes 9319 cells.
# Loaded 52405 cells after QC from well C06.
# Done processing well C/06/0
# Done concatenating data for well C/06/0
# Removing FOV_71 from well F11 due to registration errors. This removes 578 cells.
# Removing missegmented cells from F11: This removes 6603 cells.
# Loaded 49810 cells after QC from well F11.
# Done processing well F/11/0
# Done concatenating data for well F/11/0
# Removing FOV_7 from well G04 due to registration errors. This removes 961 cells.
# Removing FOV_8 from well G04 due to registration errors. This removes 710 cells.
# Removing FOV_15 from well G04 due to registration errors. This removes 1190 cells.
# Removing FOV_16 from well G04 due to registration errors. This removes 817 cells.
# Removing FOV_23 from well G04 due to registration errors. This removes 1031 cells.
# Removing missegmented cells from G04: This removes 4429 cells.
# Loaded 48899 cells after QC from well G04.
# Done processing well G/04/0
# Done concatenating data for well G/04/0
# Removing missegmented cells from G06: This removes 1930 cells.
# Loaded 42054 cells after QC from well G06.
# Done processing well G/06/0
# Done concatenating data for well G/06/0
# Removing missegmented cells from G08: This removes 1875 cells.
# Loaded 45353 cells after QC from well G08.
# Done processing well G/08/0
# Done concatenating data for well G/08/0
# Removing missegmented cells from G10: This removes 7515 cells.
# Loaded 66760 cells after QC from well G10.
# Done processing well G/10/0
# Done concatenating data for well G/10/0
# Total number of removed cells during QC: 167691
#  - of which 21949 due to registration errors, and 145742 due to missegmentation.

# %%
remaining_acquisitions
# Out:
# []

# %%
print(f"Total number of removed cells during QC: {counter_qc}")
print(
    f" - of which {counter_registration} due to registration errors, "
    f"and {counter_segmentation} due to missegmentation."
)
# Out:
# Total number of removed cells during QC: 167691
#  - of which 21949 due to registration errors, and 145742 due to missegmentation.

# %%
concatenated_df = concatenated_df.merge(
    lookup,
    how="left",
    left_on="well_name",
    right_on="well",
)
concatenated_df = concatenated_df.drop(columns=["well"])
concatenated_df
# Out:
#          label  nuclei_filtered_Morphology_area  \
# 0            1                           3997.0
# 1            2                           4307.0
# 2            4                           2322.0
# 3            5                           2195.0
# 4            6                           3996.0
# ...        ...                              ...
# 1041835  74238                           1562.0
# 1041836  74239                           1345.0
# 1041837  74242                           1233.0
# 1041838  74246                           1390.0
# 1041839  74249                           1377.0
#
#          nuclei_filtered_Morphology_centroid-0  \
# 0                                    70.500122
# 1                                    38.224518
# 2                                    23.260983
# 3                                    21.335764
# 4                                    33.656155
# ...                                        ...
# 1041835                            2148.081299
# 1041836                            2147.655029
# 1041837                            2148.418457
# 1041838                            2148.655518
# 1041839                            2149.809082
#
#          nuclei_filtered_Morphology_centroid-1  \
# 0                                    56.327995
# 1                                   545.921082
# 2                                   817.758850
# 3                                   875.819153
# 4                                   949.489502
# ...                                        ...
# 1041835                            1152.081909
# 1041836                            1777.846802
# 1041837                            1085.787476
# 1041838                             431.275543
# 1041839                            1447.402344
#
#          nuclei_filtered_Morphology_well_centroid-0  \
# 0                                         70.500122
# 1                                         38.224518
# 2                                         23.260983
# 3                                         21.335764
# 4                                         33.656155
# ...                                             ...
# 1041835                                19428.082031
# 1041836                                19427.654297
# 1041837                                19428.417969
# 1041838                                19428.656250
# 1041839                                19429.808594
#
#          nuclei_filtered_Morphology_well_centroid-1  \
# 0                                         56.327995
# 1                                        545.921082
# 2                                        817.758850
# 3                                        875.819153
# 4                                        949.489502
# ...                                             ...
# 1041835                                 3712.082031
# 1041836                                 6897.846680
# 1041837                                 8765.787109
# 1041838                                  431.275543
# 1041839                                 9127.402344
#
#          nuclei_filtered_Morphology_bbox_area  \
# 0                                     10472.0
# 1                                      5727.0
# 2                                      3213.0
# 3                                      2703.0
# 4                                      5688.0
# ...                                       ...
# 1041835                                2100.0
# 1041836                                1708.0
# 1041837                                1534.0
# 1041838                                1675.0
# 1041839                                1794.0
#
#          nuclei_filtered_Morphology_bbox-0  nuclei_filtered_Morphology_bbox-1  \
# 0                                      0.0                               19.0
# 1                                      0.0                              509.0
# 2                                      0.0                              786.0
# 3                                      0.0                              849.0
# 4                                      0.0                              909.0
# ...                                    ...                                ...
# 1041835                             2132.0                             1114.0
# 1041836                             2132.0                             1748.0
# 1041837                             2134.0                             1056.0
# 1041838                             2135.0                              398.0
# 1041839                             2137.0                             1409.0
#
#          nuclei_filtered_Morphology_bbox-2  ...  is_border_internal  \
# 0                                    136.0  ...                 0.0
# 1                                     83.0  ...                 0.0
# 2                                     51.0  ...                 0.0
# 3                                     51.0  ...                 0.0
# 4                                     79.0  ...                 0.0
# ...                                    ...  ...                 ...
# 1041835                             2160.0  ...                 0.0
# 1041836                             2160.0  ...                 0.0
# 1041837                             2160.0  ...                 0.0
# 1041838                             2160.0  ...                 0.0
# 1041839                             2160.0  ...                 0.0
#
#          is_border_external  well_name     ROI  segmentation_qc  \
# 0                       1.0        B09   FOV_1    Regular cells
# 1                       1.0        B09   FOV_1    Regular cells
# 2                       1.0        B09   FOV_1    Regular cells
# 3                       1.0        B09   FOV_1    Regular cells
# 4                       1.0        B09   FOV_1    Regular cells
# ...                     ...        ...     ...              ...
# 1041835                 1.0        G10  FOV_66    Regular cells
# 1041836                 1.0        G10  FOV_67    Regular cells
# 1041837                 1.0        G10  FOV_68    Regular cells
# 1041838                 1.0        G10  FOV_65    Regular cells
# 1041839                 1.0        G10  FOV_68    Regular cells
#
#          nanog_classifier  Sox17_classifier  NKX25_classifier  \
# 0          nanog_negative    Sox17_negative    NKX25_negative
# 1          nanog_negative    Sox17_positive    NKX25_negative
# 2          nanog_negative    Sox17_negative    NKX25_negative
# 3          nanog_negative    Sox17_negative    NKX25_negative
# 4          nanog_negative    Sox17_negative    NKX25_negative
# ...                   ...               ...               ...
# 1041835    nanog_negative    Sox17_negative    NKX25_negative
# 1041836    nanog_negative    Sox17_negative    NKX25_negative
# 1041837    nanog_negative    Sox17_negative    NKX25_negative
# 1041838    nanog_negative    Sox17_negative    NKX25_negative
# 1041839    nanog_negative    Sox17_negative    NKX25_negative
#
#          TroponinT_classifier  differentiation_day
# 0          TroponinT_negative                    5
# 1          TroponinT_negative                    5
# 2          TroponinT_negative                    5
# 3          TroponinT_negative                    5
# 4          TroponinT_negative                    5
# ...                       ...                  ...
# 1041835    TroponinT_negative                    6
# 1041836    TroponinT_negative                    6
# 1041837    TroponinT_negative                    6
# 1041838    TroponinT_negative                    6
# 1041839    TroponinT_negative                    6
#
# [1041840 rows x 2702 columns]

# %%
from ngio.tables import FeatureTable
aggregated_ngio_table = FeatureTable(
    table_data=concatenated_df,
    reference_label="nuclei_filtered",
)

local_plate_url = "/Users/joel/Documents/TestDatasets/23well_benchmark/20200812-CardiomyocyteDifferentiation14-Cycle1_mip.zarr"
local_plate = ngio.open_ome_zarr_plate(local_plate_url)
local_plate.add_table(
    name="nuclei_measurements_initial_qced",
    table=aggregated_ngio_table,
    backend="parquet",
    overwrite=True,
)

# %%
print(list(concatenated_df.columns))
# Out:
# ['label', 'nuclei_filtered_Morphology_area', 'nuclei_filtered_Morphology_centroid-0', 'nuclei_filtered_Morphology_centroid-1', 'nuclei_filtered_Morphology_well_centroid-0', 'nuclei_filtered_Morphology_well_centroid-1', 'nuclei_filtered_Morphology_bbox_area', 'nuclei_filtered_Morphology_bbox-0', 'nuclei_filtered_Morphology_bbox-1', 'nuclei_filtered_Morphology_bbox-2', 'nuclei_filtered_Morphology_bbox-3', 'nuclei_filtered_Morphology_convex_area', 'nuclei_filtered_Morphology_eccentricity', 'nuclei_filtered_Morphology_equivalent_diameter', 'nuclei_filtered_Morphology_euler_number', 'nuclei_filtered_Morphology_extent', 'nuclei_filtered_Morphology_filled_area', 'nuclei_filtered_Morphology_major_axis_length', 'nuclei_filtered_Morphology_minor_axis_length', 'nuclei_filtered_Morphology_orientation', 'nuclei_filtered_Morphology_perimeter', 'nuclei_filtered_Morphology_solidity', 'nuclei_filtered_Morphology_roundness', 'nuclei_filtered_Intensity_max_intensity_DAPI_1', 'nuclei_filtered_Intensity_mean_intensity_DAPI_1', 'nuclei_filtered_Intensity_min_intensity_DAPI_1', 'nuclei_filtered_Intensity_sum_intensity_DAPI_1', 'nuclei_filtered_Intensity_std_intensity_DAPI_1', 'nuclei_filtered_Intensity_max_intensity_Isl1', 'nuclei_filtered_Intensity_mean_intensity_Isl1', 'nuclei_filtered_Intensity_min_intensity_Isl1', 'nuclei_filtered_Intensity_sum_intensity_Isl1', 'nuclei_filtered_Intensity_std_intensity_Isl1', 'nuclei_filtered_Intensity_max_intensity_NaKATPase', 'nuclei_filtered_Intensity_mean_intensity_NaKATPase', 'nuclei_filtered_Intensity_min_intensity_NaKATPase', 'nuclei_filtered_Intensity_sum_intensity_NaKATPase', 'nuclei_filtered_Intensity_std_intensity_NaKATPase', 'nuclei_filtered_Intensity_max_intensity_DAPI_0', 'nuclei_filtered_Intensity_mean_intensity_DAPI_0', 'nuclei_filtered_Intensity_min_intensity_DAPI_0', 'nuclei_filtered_Intensity_sum_intensity_DAPI_0', 'nuclei_filtered_Intensity_std_intensity_DAPI_0', 'nuclei_filtered_Intensity_max_intensity_nanog', 'nuclei_filtered_Intensity_mean_intensity_nanog', 'nuclei_filtered_Intensity_min_intensity_nanog', 'nuclei_filtered_Intensity_sum_intensity_nanog', 'nuclei_filtered_Intensity_std_intensity_nanog', 'nuclei_filtered_Intensity_max_intensity_Lamin B1', 'nuclei_filtered_Intensity_mean_intensity_Lamin B1', 'nuclei_filtered_Intensity_min_intensity_Lamin B1', 'nuclei_filtered_Intensity_sum_intensity_Lamin B1', 'nuclei_filtered_Intensity_std_intensity_Lamin B1', 'nuclei_filtered_Intensity_max_intensity_DAPI_2', 'nuclei_filtered_Intensity_mean_intensity_DAPI_2', 'nuclei_filtered_Intensity_min_intensity_DAPI_2', 'nuclei_filtered_Intensity_sum_intensity_DAPI_2', 'nuclei_filtered_Intensity_std_intensity_DAPI_2', 'nuclei_filtered_Intensity_max_intensity_Sox17', 'nuclei_filtered_Intensity_mean_intensity_Sox17', 'nuclei_filtered_Intensity_min_intensity_Sox17', 'nuclei_filtered_Intensity_sum_intensity_Sox17', 'nuclei_filtered_Intensity_std_intensity_Sox17', 'nuclei_filtered_Intensity_max_intensity_BMP4', 'nuclei_filtered_Intensity_mean_intensity_BMP4', 'nuclei_filtered_Intensity_min_intensity_BMP4', 'nuclei_filtered_Intensity_sum_intensity_BMP4', 'nuclei_filtered_Intensity_std_intensity_BMP4', 'nuclei_filtered_Intensity_max_intensity_DAPI_4', 'nuclei_filtered_Intensity_mean_intensity_DAPI_4', 'nuclei_filtered_Intensity_min_intensity_DAPI_4', 'nuclei_filtered_Intensity_sum_intensity_DAPI_4', 'nuclei_filtered_Intensity_std_intensity_DAPI_4', 'nuclei_filtered_Intensity_max_intensity_EOMES', 'nuclei_filtered_Intensity_mean_intensity_EOMES', 'nuclei_filtered_Intensity_min_intensity_EOMES', 'nuclei_filtered_Intensity_sum_intensity_EOMES', 'nuclei_filtered_Intensity_std_intensity_EOMES', 'nuclei_filtered_Intensity_max_intensity_GATA4', 'nuclei_filtered_Intensity_mean_intensity_GATA4', 'nuclei_filtered_Intensity_min_intensity_GATA4', 'nuclei_filtered_Intensity_sum_intensity_GATA4', 'nuclei_filtered_Intensity_std_intensity_GATA4', 'nuclei_filtered_Intensity_max_intensity_DAPI_5', 'nuclei_filtered_Intensity_mean_ ...

# %%
# Optionally reload the table from disk
local_plate_url = "/Users/joel/Documents/TestDatasets/23well_benchmark/20200812-CardiomyocyteDifferentiation14-Cycle1_mip.zarr"
local_plate = ngio.open_ome_zarr_plate(local_plate_url)
concatenated_df = local_plate.get_table("nuclei_measurements_initial_qced").dataframe

# %%
# # Additional QC filters
# concatenated_df = concatenated_df[concatenated_df["nuclei_filtered_Morphology_solidity"] > 0.8]
# # Get rid of additional cells with registration artefacts or detachment in later cycles
# concatenated_df = concatenated_df[concatenated_df["nuclei_filtered_Intensity_mean_intensity_DAPI_12"] > 30]
# concatenated_df = concatenated_df[concatenated_df["nuclei_filtered_Intensity_mean_intensity_DAPI_13"] > 30]
# concatenated_df = concatenated_df[concatenated_df["nuclei_filtered_Texture_Haralick-Mean-angular-second-moment-5_bTubulin"] > 0.4]

# Additional QC filters
# Missegmented objects by shape &
# Get rid of additional cells with registration artefacts, detachment in later cycles or staining artefacts
m = concatenated_df["nuclei_filtered_Morphology_solidity"] > 0.8
m &= concatenated_df["nuclei_filtered_Intensity_mean_intensity_DAPI_12"] > 30
m &= concatenated_df["nuclei_filtered_Intensity_mean_intensity_DAPI_13"] > 30
m &= concatenated_df["nuclei_filtered_Texture_Haralick-Mean-angular-second-moment-5_bTubulin"] < 0.4
m &= concatenated_df["nuclei_filtered_Texture_Haralick-Range-sum-of-squares-5_nanog"] < 20
m &= concatenated_df["nuclei_filtered_Texture_Haralick-Range-contrast-5_nanog"] < 50
m &= concatenated_df["nuclei_filtered_Texture_Haralick-Range-angular-second-moment-5_DAPI_8"] < 0.02

concatenated_df = concatenated_df.loc[m]

# %%
concatenated_df
# Out:
#        nuclei_filtered_Morphology_area  nuclei_filtered_Morphology_centroid-0  \
# label
# 1                               3997.0                              70.500122
# 2                               4307.0                              38.224518
# 8                               2784.0                              40.610271
# 16                              6682.0                              36.439690
# 17                              6500.0                              40.313694
# ...                                ...                                    ...
# 74238                           1562.0                            2148.081299
# 74239                           1345.0                            2147.655029
# 74242                           1233.0                            2148.418457
# 74246                           1390.0                            2148.655518
# 74249                           1377.0                            2149.809082
#
#        nuclei_filtered_Morphology_centroid-1  \
# label
# 1                                  56.327995
# 2                                 545.921082
# 8                                1056.926392
# 16                                 50.263542
# 17                                192.697540
# ...                                      ...
# 74238                            1152.081909
# 74239                            1777.846802
# 74242                            1085.787476
# 74246                             431.275543
# 74249                            1447.402344
#
#        nuclei_filtered_Morphology_well_centroid-0  \
# label
# 1                                       70.500122
# 2                                       38.224518
# 8                                       40.610271
# 16                                      36.439690
# 17                                      40.313694
# ...                                           ...
# 74238                                19428.082031
# 74239                                19427.654297
# 74242                                19428.417969
# 74246                                19428.656250
# 74249                                19429.808594
#
#        nuclei_filtered_Morphology_well_centroid-1  \
# label
# 1                                       56.327995
# 2                                      545.921082
# 8                                     1056.926392
# 16                                    2610.263428
# 17                                    2752.697510
# ...                                           ...
# 74238                                 3712.082031
# 74239                                 6897.846680
# 74242                                 8765.787109
# 74246                                  431.275543
# 74249                                 9127.402344
#
#        nuclei_filtered_Morphology_bbox_area  \
# label
# 1                                   10472.0
# 2                                    5727.0
# 8                                    4674.0
# 16                                   8938.0
# 17                                   7826.0
# ...                                     ...
# 74238                                2100.0
# 74239                                1708.0
# 74242                                1534.0
# 74246                                1675.0
# 74249                                1794.0
#
#        nuclei_filtered_Morphology_bbox-0  nuclei_filtered_Morphology_bbox-1  \
# label
# 1                                    0.0                               19.0
# 2                                    0.0                              509.0
# 8                                    0.0                             1034.0
# 16                                   0.0                                0.0
# 17                                   0.0                              145.0
# ...                                  ...                                ...
# 74238                             2132.0                             1114.0
# 74239                             2132.0                             1748.0
# 74242                             2134.0                             1056.0
# 74246                             2135.0                              398.0
# 74249                             2137.0                             1409.0
#
#        nuclei_filtered_Morphology_bbox-2  nuclei_filtered_Morphology_bbox-3  \
# label
# 1                                  136.0                               96.0
# 2                                   83.0                              578.0
# 8                                   82.0                             1091.0
# 16                                  82.0                              109.0
# 17                                  86.0                              236.0
# ...                                  ...                                ...
# 74238                             2160.0                             1189.0
# 74239                             2160.0                             1809.0
# 74242                             2160.0                             1115.0
# 74246                             2160.0                              465.0
# 74249                             2160.0                             1487.0
#
#        ...  is_border_internal  is_border_external  well_name     ROI  \
# label  ...
# 1      ...                 0.0                 1.0        B09   FOV_1
# 2      ...                 0.0                 1.0        B09   FOV_1
# 8      ...                 0.0                 1.0        B09   FOV_1
# 16     ...                 1.0                 1.0        B09   FOV_2
# 17     ...                 0.0                 1.0        B09   FOV_2
# ...    ...                 ...                 ...        ...     ...
# 74238  ...                 0.0                 1.0        G10  FOV_66
# 74239  ...                 0.0                 1.0        G10  FOV_67
# 74242  ...                 0.0                 1.0        G10  FOV_68
# 74246  ...                 0.0                 1.0        G10  FOV_65
# 74249  ...                 0.0                 1.0        G10  FOV_68
#
#        segmentation_qc  nanog_classifier  Sox17_classifier  NKX25_classifier  \
# label
# 1        Regular cells    nanog_negative    Sox17_negative    NKX25_negative
# 2        Regular cells    nanog_negative    Sox17_positive    NKX25_negative
# 8        Regular cells    nanog_negative    Sox17_positive    NKX25_positive
# 16       Regular cells    nanog_negative    Sox17_negative    NKX25_negative
# 17       Regular cells    nanog_negative    Sox17_negative    NKX25_negative
# ...                ...               ...               ...               ...
# 74238    Regular cells    nanog_negative    Sox17_negative    NKX25_negative
# 74239    Regular cells    nanog_negative    Sox17_negative    NKX25_negative
# 74242    Regular cells    nanog_negative    Sox17_negative    NKX25_negative
# 74246    Regular cells    nanog_negative    Sox17_negative    NKX25_negative
# 74249    Regular cells    nanog_negative    Sox17_negative    NKX25_negative
#
#        TroponinT_classifier  differentiation_day
# label
# 1        TroponinT_negative                    5
# 2        TroponinT_negative                    5
# 8        TroponinT_negative                    5
# 16       TroponinT_negative                    5
# 17       TroponinT_negative                    5
# ...                     ...                  ...
# 74238    TroponinT_negative                    6
# 74239    TroponinT_negative                    6
# 74242    TroponinT_negative                    6
# 74246    TroponinT_negative                    6
# 74249    TroponinT_negative                    6
#
# [949161 rows x 2701 columns]

# %%
cols_to_drop = [
    "nuclei_filtered_Population_mean_distance_nn_100",
    "nuclei_filtered_Population_mean_distance_nn_50",
]

concatenated_df.drop(columns=cols_to_drop, inplace=True)
concatenated_df.dropna(
    subset=["nuclei_filtered_Population_mean_distance_nn_25"],
    inplace=True,
)

# %%
margin = 70

to_discard = (
    (concatenated_df["nuclei_filtered_Morphology_bbox-0"] < margin)
    | (concatenated_df["nuclei_filtered_Morphology_bbox-1"] < margin)
    | (concatenated_df["nuclei_filtered_Morphology_bbox-2"] > 2160 - margin)
    | (concatenated_df["nuclei_filtered_Morphology_bbox-3"] > 2560 - margin)
)
concatenated_df = concatenated_df.loc[~to_discard]

# %%
# Columns to drop because they are static
# static_cols = concatenated_df.nunique(dropna=True) <= 1
# static_columns = static_cols[static_cols].index.tolist()
# print(static_columns)

cols_to_drop = [
    'nuclei_filtered_Morphology_euler_number',
    'is_border_internal',
    'is_border_external',
    'segmentation_qc'
]

concatenated_df.drop(columns=cols_to_drop, inplace=True)
# Out:
# /var/folders/sk/fl32m0g97kv2xlqz9f0p5bbm0000gr/T/ipykernel_96420/678505001.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   concatenated_df.drop(columns=cols_to_drop, inplace=True)

# %%
concatenated_df
# Out:
#        nuclei_filtered_Morphology_area  nuclei_filtered_Morphology_centroid-0  \
# label
# 255                             1903.0                              92.464005
# 256                             5027.0                             116.085739
# 257                             5443.0                             115.766121
# 258                             1885.0                              88.706100
# 260                             3257.0                             109.134483
# ...                                ...                                    ...
# 73863                           2531.0                            2050.525391
# 73865                           3891.0                            2052.596680
# 73867                           3534.0                            2054.503662
# 73882                           2781.0                            2059.787109
# 73890                           3344.0                            2054.797852
#
#        nuclei_filtered_Morphology_centroid-1  \
# label
# 255                               647.835022
# 256                              1196.467529
# 257                               880.044617
# 258                              2075.311523
# 260                               793.915588
# ...                                      ...
# 73863                             984.713562
# 73865                            1219.142334
# 73867                             152.179688
# 73882                             274.611664
# 73890                            1755.095703
#
#        nuclei_filtered_Morphology_well_centroid-0  \
# label
# 255                                     92.464005
# 256                                    116.085739
# 257                                    115.766121
# 258                                     88.706100
# 260                                    109.134483
# ...                                           ...
# 73863                                19330.525391
# 73865                                19332.597656
# 73867                                19334.503906
# 73882                                19339.787109
# 73890                                19334.796875
#
#        nuclei_filtered_Morphology_well_centroid-1  \
# label
# 255                                  16007.834961
# 256                                  16556.466797
# 257                                  11120.044922
# 258                                  12315.311523
# 260                                   5913.915527
# ...                                           ...
# 73863                                 8664.713867
# 73865                                14019.142578
# 73867                                 7832.179688
# 73882                                  274.611664
# 73890                                 9435.095703
#
#        nuclei_filtered_Morphology_bbox_area  \
# label
# 255                                  2958.0
# 256                                  8544.0
# 257                                  7209.0
# 258                                  3060.0
# 260                                  4422.0
# ...                                     ...
# 73863                                3074.0
# 73865                                5900.0
# 73867                                4920.0
# 73882                                3710.0
# 73890                                4747.0
#
#        nuclei_filtered_Morphology_bbox-0  nuclei_filtered_Morphology_bbox-1  \
# label
# 255                                 70.0                              615.0
# 256                                 70.0                             1149.0
# 257                                 71.0                              838.0
# 258                                 71.0                             2031.0
# 260                                 76.0                              761.0
# ...                                  ...                                ...
# 73863                             2025.0                              956.0
# 73865                             2025.0                             1165.0
# 73867                             2026.0                              110.0
# 73882                             2032.0                              241.0
# 73890                             2034.0                             1708.0
#
#        nuclei_filtered_Morphology_bbox-2  nuclei_filtered_Morphology_bbox-3  \
# label
# 255                                121.0                              673.0
# 256                                159.0                             1245.0
# 257                                160.0                              919.0
# 258                                107.0                             2116.0
# 260                                142.0                              828.0
# ...                                  ...                                ...
# 73863                             2078.0                             1014.0
# 73865                             2084.0                             1265.0
# 73867                             2086.0                              192.0
# 73882                             2085.0                              311.0
# 73890                             2081.0                             1809.0
#
#        ...  nuclei_filtered_Population_mean_distance_neighbours_radius_400  \
# label  ...
# 255    ...                                         240.234253
# 256    ...                                         262.938599
# 257    ...                                         237.428467
# 258    ...                                         231.332306
# 260    ...                                         259.891663
# ...    ...                                                ...
# 73863  ...                                         250.595825
# 73865  ...                                         264.738525
# 73867  ...                                         213.656281
# 73882  ...                                         230.830887
# 73890  ...                                         240.750290
#
#        nuclei_filtered_Population_n_neighbours_radius_500  \
# label
# 255                                                 69.0
# 256                                                 57.0
# 257                                                 38.0
# 258                                                 36.0
# 260                                                 43.0
# ...                                                  ...
# 73863                                              113.0
# 73865                                              123.0
# 73867                                               64.0
# 73882                                               58.0
# 73890                                              123.0
#
#        nuclei_filtered_Population_mean_distance_neighbours_radius_500  \
# label
# 255                                           306.196106
# 256                                           335.310944
# 257                                           305.473389
# 258                                           308.513672
# 260                                           333.262085
# ...                                                  ...
# 73863                                         319.164124
# 73865                                         324.402985
# 73867                                         284.033661
# 73882                                         277.547516
# 73890                                         311.738892
#
#        well_name     ROI  nanog_classifier  Sox17_classifier  \
# label
# 255          B09   FOV_7    nanog_negative    Sox17_negative
# 256          B09   FOV_7    nanog_negative    Sox17_negative
# 257          B09   FOV_5    nanog_negative    Sox17_positive
# 258          B09   FOV_5    nanog_negative    Sox17_negative
# 260          B09   FOV_3    nanog_negative    Sox17_positive
# ...          ...     ...               ...               ...
# 73863        G10  FOV_68    nanog_negative    Sox17_negative
# 73865        G10  FOV_70    nanog_negative    Sox17_negative
# 73867        G10  FOV_68    nanog_negative    Sox17_negative
# 73882        G10  FOV_65    nanog_negative    Sox17_negative
# 73890        G10  FOV_68    nanog_negative    Sox17_negative
#
#        NKX25_classifier  TroponinT_classifier  differentiation_day
# label
# 255      NKX25_negative    TroponinT_negative                    5
# 256      NKX25_negative    TroponinT_negative                    5
# 257      NKX25_negative    TroponinT_negative                    5
# 258      NKX25_negative    TroponinT_negative                    5
# 260      NKX25_negative    TroponinT_negative                    5
# ...                 ...                   ...                  ...
# 73863    NKX25_negative    TroponinT_positive                    6
# 73865    NKX25_negative    TroponinT_negative                    6
# 73867    NKX25_positive    TroponinT_negative                    6
# 73882    NKX25_negative    TroponinT_negative                    6
# 73890    NKX25_negative    TroponinT_negative                    6
#
# [826606 rows x 2695 columns]

# %%
# Save QCed table to disk
from ngio.tables import FeatureTable
qc_ngio_table = FeatureTable(
    table_data=concatenated_df,
    reference_label="nuclei_filtered",
)

local_plate_url = "/Users/joel/Documents/TestDatasets/23well_benchmark/20200812-CardiomyocyteDifferentiation14-Cycle1_mip.zarr"
local_plate = ngio.open_ome_zarr_plate(local_plate_url)
local_plate.add_table(
    name="nuclei_measurements_qced",
    table=qc_ngio_table,
    backend="parquet",
    overwrite=True,
)

# %%
CLASSIFIERS = {
    "nanog_classifier": "nanog_positive",
    "Sox17_classifier": "Sox17_positive",
    "NKX25_classifier": "NKX25_positive",
    "TroponinT_classifier": "TroponinT_positive",
}

rows = []

for clf_col, pos_label in CLASSIFIERS.items():
    tmp = (
        concatenated_df
        .assign(is_positive=lambda d: d[clf_col] == pos_label)
        .groupby("differentiation_day")
        .agg(
            n_cells=("is_positive", "size"),
            n_positive=("is_positive", "sum"),
        )
        .reset_index()
    )

    tmp["percent_positive"] = 100 * tmp["n_positive"] / tmp["n_cells"]
    tmp["classifier"] = clf_col

    rows.append(tmp)

summary_df = pd.concat(rows, ignore_index=True)
summary_df
# Out:
#     differentiation_day  n_cells  n_positive  percent_positive  \
# 0                     0   134502      128907         95.840211
# 1                     1    55680       54067         97.103089
# 2                     2    48406       38448         79.428170
# 3                     3    29586        7625         25.772325
# 4                     4    66873        3665          5.480538
# 5                     5    65437        1222          1.867445
# 6                     6    98287         286          0.290985
# 7                     7   107978          91          0.084276
# 8                     8   103751         116          0.111806
# 9                     9    86645          62          0.071556
# 10                   10    85766          47          0.054800
# 11                    0   134502          36          0.026765
# 12                    1    55680         462          0.829741
# 13                    2    48406         223          0.460687
# 14                    3    29586        7065         23.879538
# 15                    4    66873       16606         24.832145
# 16                    5    65437       13266         20.272934
# 17                    6    98287         659          0.670485
# 18                    7   107978          58          0.053715
# 19                    8   103751         292          0.281443
# 20                    9    86645          48          0.055398
# 21                   10    85766         148          0.172563
# 22                    0   134502          42          0.031226
# 23                    1    55680         772          1.386494
# 24                    2    48406        1749          3.613188
# 25                    3    29586         786          2.656662
# 26                    4    66873         338          0.505436
# 27                    5    65437        6413          9.800266
# 28                    6    98287       32650         33.219042
# 29                    7   107978       71438         66.159773
# 30                    8   103751       85141         82.062823
# 31                    9    86645       67300         77.673264
# 32                   10    85766       72202         84.184875
# 33                    0   134502         307          0.228249
# 34                    1    55680        3938          7.072557
# 35                    2    48406        1018          2.103045
# 36                    3    29586         212          0.716555
# 37                    4    66873         385          0.575718
# 38                    5    65437         592          0.904687
# 39                    6    98287       36770         37.410848
# 40                    7   107978       75985         70.370816
# 41                    8   103751       78051         75.229154
# 42                    9    86645       49460         57.083502
# 43                   10    85766       45379         52.910244
#
#               classifier
# 0       nanog_classifier
# 1       nanog_classifier
# 2       nanog_classifier
# 3       nanog_classifier
# 4       nanog_classifier
# 5       nanog_classifier
# 6       nanog_classifier
# 7       nanog_classifier
# 8       nanog_classifier
# 9       nanog_classifier
# 10      nanog_classifier
# 11      Sox17_classifier
# 12      Sox17_classifier
# 13      Sox17_classifier
# 14      Sox17_classifier
# 15      Sox17_classifier
# 16      Sox17_classifier
# 17      Sox17_classifier
# 18      Sox17_classifier
# 19      Sox17_classifier
# 20      Sox17_classifier
# 21      Sox17_classifier
# 22      NKX25_classifier
# 23      NKX25_classifier
# 24      NKX25_classifier
# 25      NKX25_classifier
# 26      NKX25_classifier
# 27      NKX25_classifier
# 28      NKX25_classifier
# 29      NKX25_classifier
# 30      NKX25_classifier
# 31      NKX25_classifier
# 32      NKX25_classifier
# 33  TroponinT_classifier
# 34  TroponinT_classifier
# 35  TroponinT_classifier
# 36  TroponinT_classifier
# 37  TroponinT_classifier
# 38  TroponinT_classifier
# 39  TroponinT_classifier
# 40  TroponinT_classifier
# 41  TroponinT_classifier
# 42  TroponinT_classifier
# 43  TroponinT_classifier

# %%
summary_df.pivot(
    index="differentiation_day",
    columns="classifier",
    values="percent_positive",
)
# Out:
# classifier           NKX25_classifier  Sox17_classifier  TroponinT_classifier  \
# differentiation_day
# 0                            0.031226          0.026765              0.228249
# 1                            1.386494          0.829741              7.072557
# 2                            3.613188          0.460687              2.103045
# 3                            2.656662         23.879538              0.716555
# 4                            0.505436         24.832145              0.575718
# 5                            9.800266         20.272934              0.904687
# 6                           33.219042          0.670485             37.410848
# 7                           66.159773          0.053715             70.370816
# 8                           82.062823          0.281443             75.229154
# 9                           77.673264          0.055398             57.083502
# 10                          84.184875          0.172563             52.910244
#
# classifier           nanog_classifier
# differentiation_day
# 0                           95.840211
# 1                           97.103089
# 2                           79.428170
# 3                           25.772325
# 4                            5.480538
# 5                            1.867445
# 6                            0.290985
# 7                            0.084276
# 8                            0.111806
# 9                            0.071556
# 10                           0.054800

# %% [markdown]
# # Experimentation

# %%
concatenated_df
# Out:
#          label  nuclei_filtered_Morphology_area  \
# 167        214                           6109.0
# 168        215                           4718.0
# 169        216                           4599.0
# 170        217                           8068.0
# 171        219                           3333.0
# ...        ...                              ...
# 1041597  73957                           3611.0
# 1041603  73964                           2288.0
# 1041607  73970                           2258.0
# 1041614  73978                           2402.0
# 1041632  73997                           2146.0
#
#          nuclei_filtered_Morphology_centroid-0  \
# 167                                  87.627602
# 168                                  92.093262
# 169                                  91.097412
# 170                                 101.037308
# 171                                  88.151215
# ...                                        ...
# 1041597                            2074.994385
# 1041603                            2075.985107
# 1041607                            2083.329590
# 1041614                            2074.787598
# 1041632                            2086.249268
#
#          nuclei_filtered_Morphology_centroid-1  \
# 167                                1664.032715
# 168                                 165.185242
# 169                                1477.827148
# 170                                 431.152832
# 171                                1583.671509
# ...                                        ...
# 1041597                             710.316284
# 1041603                             260.677002
# 1041607                             184.254211
# 1041614                             395.848450
# 1041632                            2250.247559
#
#          nuclei_filtered_Morphology_well_centroid-0  \
# 167                                       87.627602
# 168                                       92.093262
# 169                                       91.097412
# 170                                      101.037308
# 171                                       88.151215
# ...                                             ...
# 1041597                                19354.994141
# 1041603                                19355.984375
# 1041607                                19363.330078
# 1041614                                19354.787109
# 1041632                                19366.250000
#
#          nuclei_filtered_Morphology_well_centroid-1  \
# 167                                     9344.033203
# 168                                      165.185242
# 169                                     6597.827148
# 170                                     2991.152832
# 171                                    14383.671875
# ...                                             ...
# 1041597                                18630.316406
# 1041603                                10500.676758
# 1041607                                10424.253906
# 1041614                                18315.847656
# 1041632                                 9930.247070
#
#          nuclei_filtered_Morphology_bbox_area  \
# 167                                    8475.0
# 168                                    6162.0
# 169                                    5920.0
# 170                                    9797.0
# 171                                    4599.0
# ...                                       ...
# 1041597                                4900.0
# 1041603                                3283.0
# 1041607                                3213.0
# 1041614                                3034.0
# 1041632                                3397.0
#
#          nuclei_filtered_Morphology_bbox-0  nuclei_filtered_Morphology_bbox-1  \
# 167                                   50.0                             1613.0
# 168                                   51.0                              126.0
# 169                                   51.0                             1441.0
# 170                                   52.0                              381.0
# 171                                   52.0                             1552.0
# ...                                    ...                                ...
# 1041597                             2051.0                              660.0
# 1041603                             2054.0                              229.0
# 1041607                             2056.0                              150.0
# 1041614                             2057.0                              355.0
# 1041632                             2064.0                             2209.0
#
#          nuclei_filtered_Morphology_bbox-2  ...  \
# 167                                  125.0  ...
# 168                                  130.0  ...
# 169                                  131.0  ...
# 170                                  149.0  ...
# 171                                  125.0  ...
# ...                                    ...  ...
# 1041597                             2100.0  ...
# 1041603                             2103.0  ...
# 1041607                             2107.0  ...
# 1041614                             2094.0  ...
# 1041632                             2107.0  ...
#
#          nuclei_filtered_Population_mean_distance_neighbours_radius_400  \
# 167                                             230.168839
# 168                                             259.656067
# 169                                             237.435486
# 170                                             274.269928
# 171                                             249.380447
# ...                                                    ...
# 1041597                                         215.511719
# 1041603                                         232.565338
# 1041607                                         226.796906
# 1041614                                         243.800842
# 1041632                                         239.001022
#
#          nuclei_filtered_Population_n_neighbours_radius_500  \
# 167                                                   42.0
# 168                                                   24.0
# 169                                                   40.0
# 170                                                   28.0
# 171                                                   68.0
# ...                                                    ...
# 1041597                                               55.0
# 1041603                                               81.0
# 1041607                                               73.0
# 1041614                                               62.0
# 1041632                                              102.0
#
#          nuclei_filtered_Population_mean_distance_neighbours_radius_500  \
# 167                                             302.699951
# 168                                             309.615540
# 169                                             292.548187
# 170                                             358.872559
# 171                                             310.089539
# ...                                                    ...
# 1041597                                         290.618256
# 1041603                                         282.861328
# 1041607                                         285.304626
# 1041614                                         309.414673
# 1041632                                         294.051666
#
#          well_name     ROI  nanog_classifier  Sox17_classifier  \
# 167            B09   FOV_4    nanog_negative    Sox17_negative
# 168            B09   FOV_1    nanog_negative    Sox17_positive
# 169            B09   FOV_3    nanog_negative    Sox17_positive
# 170            B09   FOV_2    nanog_negative    Sox17_negative
# 171            B09   FOV_6    nanog_negative    Sox17_negative
# ...            ...     ...               ...               ...
# 1041597        G10  FOV_72    nanog_negative    Sox17_negative
# 1041603        G10  FOV_69    nanog_negative    Sox17_negative
# 1041607        G10  FOV_69    nanog_negative    Sox17_negative
# 1041614        G10  FOV_72    nanog_negative    Sox17_negative
# 1041632        G10  FOV_68    nanog_negative    Sox17_negative
#
#          NKX25_classifier  TroponinT_classifier  differentiation_day
# 167        NKX25_negative    TroponinT_negative                    5
# 168        NKX25_negative    TroponinT_negative                    5
# 169        NKX25_negative    TroponinT_negative                    5
# 170        NKX25_negative    TroponinT_negative                    5
# 171        NKX25_negative    TroponinT_negative                    5
# ...                   ...                   ...                  ...
# 1041597    NKX25_negative    TroponinT_negative                    6
# 1041603    NKX25_positive    TroponinT_negative                    6
# 1041607    NKX25_positive    TroponinT_positive                    6
# 1041614    NKX25_negative    TroponinT_positive                    6
# 1041632    NKX25_positive    TroponinT_negative                    6
#
# [882911 rows x 1184 columns]

# %%
na_counts = concatenated_df.isna().sum()

# %%
na_counts_sorted = na_counts.sort_values(ascending=False)
na_counts_sorted[na_counts_sorted > 0]
# Out:
# Series([], dtype: int64)

# %%
sum(concatenated_df["is_border_external"] == 1.0)
# Out:
# 0

# %%
sum(concatenated_df["is_border_internal"] == 1.0)
# Out:
# 0

# %%
margin = 50
print(sum(concatenated_df["nuclei_filtered_Morphology_bbox-0"] < margin))
print(sum(concatenated_df["nuclei_filtered_Morphology_bbox-1"] < margin))
print(sum(concatenated_df["nuclei_filtered_Morphology_bbox-2"] > 2160 - margin))
print(sum(concatenated_df["nuclei_filtered_Morphology_bbox-3"] > 2560 -margin))
# Out:
# 42422
# 35370
# 41367
# 34870

# %%
margin = 50

to_discard = (
    (concatenated_df["nuclei_filtered_Morphology_bbox-0"] < margin)
    | (concatenated_df["nuclei_filtered_Morphology_bbox-1"] < margin)
    | (concatenated_df["nuclei_filtered_Morphology_bbox-2"] > 2160 - margin)
    | (concatenated_df["nuclei_filtered_Morphology_bbox-3"] > 2560 - margin)
)
sum(to_discard)
# Out:
# 148510

# %%
concatenated_df = concatenated_df.loc[~to_discard]

# %%
sum(concatenated_df[~to_discard]["is_border_external"] == 1.0)

# %%
sum(concatenated_df[~to_discard]["is_border_internal"] == 1.0)
# Out:
# 0

# %%
concatenated_df
# Out:
#          label  nuclei_filtered_Morphology_area  \
# 167        214                           6109.0
# 168        215                           4718.0
# 169        216                           4599.0
# 170        217                           8068.0
# 171        219                           3333.0
# ...        ...                              ...
# 1041597  73957                           3611.0
# 1041603  73964                           2288.0
# 1041607  73970                           2258.0
# 1041614  73978                           2402.0
# 1041632  73997                           2146.0
#
#          nuclei_filtered_Morphology_centroid-0  \
# 167                                  87.627602
# 168                                  92.093262
# 169                                  91.097412
# 170                                 101.037308
# 171                                  88.151215
# ...                                        ...
# 1041597                            2074.994385
# 1041603                            2075.985107
# 1041607                            2083.329590
# 1041614                            2074.787598
# 1041632                            2086.249268
#
#          nuclei_filtered_Morphology_centroid-1  \
# 167                                1664.032715
# 168                                 165.185242
# 169                                1477.827148
# 170                                 431.152832
# 171                                1583.671509
# ...                                        ...
# 1041597                             710.316284
# 1041603                             260.677002
# 1041607                             184.254211
# 1041614                             395.848450
# 1041632                            2250.247559
#
#          nuclei_filtered_Morphology_well_centroid-0  \
# 167                                       87.627602
# 168                                       92.093262
# 169                                       91.097412
# 170                                      101.037308
# 171                                       88.151215
# ...                                             ...
# 1041597                                19354.994141
# 1041603                                19355.984375
# 1041607                                19363.330078
# 1041614                                19354.787109
# 1041632                                19366.250000
#
#          nuclei_filtered_Morphology_well_centroid-1  \
# 167                                     9344.033203
# 168                                      165.185242
# 169                                     6597.827148
# 170                                     2991.152832
# 171                                    14383.671875
# ...                                             ...
# 1041597                                18630.316406
# 1041603                                10500.676758
# 1041607                                10424.253906
# 1041614                                18315.847656
# 1041632                                 9930.247070
#
#          nuclei_filtered_Morphology_bbox_area  \
# 167                                    8475.0
# 168                                    6162.0
# 169                                    5920.0
# 170                                    9797.0
# 171                                    4599.0
# ...                                       ...
# 1041597                                4900.0
# 1041603                                3283.0
# 1041607                                3213.0
# 1041614                                3034.0
# 1041632                                3397.0
#
#          nuclei_filtered_Morphology_bbox-0  nuclei_filtered_Morphology_bbox-1  \
# 167                                   50.0                             1613.0
# 168                                   51.0                              126.0
# 169                                   51.0                             1441.0
# 170                                   52.0                              381.0
# 171                                   52.0                             1552.0
# ...                                    ...                                ...
# 1041597                             2051.0                              660.0
# 1041603                             2054.0                              229.0
# 1041607                             2056.0                              150.0
# 1041614                             2057.0                              355.0
# 1041632                             2064.0                             2209.0
#
#          nuclei_filtered_Morphology_bbox-2  ...  is_border_internal  \
# 167                                  125.0  ...                 0.0
# 168                                  130.0  ...                 0.0
# 169                                  131.0  ...                 0.0
# 170                                  149.0  ...                 0.0
# 171                                  125.0  ...                 0.0
# ...                                    ...  ...                 ...
# 1041597                             2100.0  ...                 0.0
# 1041603                             2103.0  ...                 0.0
# 1041607                             2107.0  ...                 0.0
# 1041614                             2094.0  ...                 0.0
# 1041632                             2107.0  ...                 0.0
#
#          is_border_external  well_name     ROI  segmentation_qc  \
# 167                     0.0        B09   FOV_4    Regular cells
# 168                     0.0        B09   FOV_1    Regular cells
# 169                     0.0        B09   FOV_3    Regular cells
# 170                     0.0        B09   FOV_2    Regular cells
# 171                     0.0        B09   FOV_6    Regular cells
# ...                     ...        ...     ...              ...
# 1041597                 0.0        G10  FOV_72    Regular cells
# 1041603                 0.0        G10  FOV_69    Regular cells
# 1041607                 0.0        G10  FOV_69    Regular cells
# 1041614                 0.0        G10  FOV_72    Regular cells
# 1041632                 0.0        G10  FOV_68    Regular cells
#
#          nanog_classifier  Sox17_classifier  NKX25_classifier  \
# 167        nanog_negative    Sox17_negative    NKX25_negative
# 168        nanog_negative    Sox17_positive    NKX25_negative
# 169        nanog_negative    Sox17_positive    NKX25_negative
# 170        nanog_negative    Sox17_negative    NKX25_negative
# 171        nanog_negative    Sox17_negative    NKX25_negative
# ...                   ...               ...               ...
# 1041597    nanog_negative    Sox17_negative    NKX25_negative
# 1041603    nanog_negative    Sox17_negative    NKX25_positive
# 1041607    nanog_negative    Sox17_negative    NKX25_positive
# 1041614    nanog_negative    Sox17_negative    NKX25_negative
# 1041632    nanog_negative    Sox17_negative    NKX25_positive
#
#          TroponinT_classifier  differentiation_day
# 167        TroponinT_negative                    5
# 168        TroponinT_negative                    5
# 169        TroponinT_negative                    5
# 170        TroponinT_negative                    5
# 171        TroponinT_negative                    5
# ...                       ...                  ...
# 1041597    TroponinT_negative                    6
# 1041603    TroponinT_negative                    6
# 1041607    TroponinT_positive                    6
# 1041614    TroponinT_positive                    6
# 1041632    TroponinT_negative                    6
#
# [882911 rows x 1188 columns]

# %%
static_cols = concatenated_df.nunique(dropna=True) <= 5
static_columns = static_cols[static_cols].index.tolist()
static_columns
# Out:
# ['nuclei_filtered_Morphology_euler_number',
#  'is_border_internal',
#  'is_border_external',
#  'segmentation_qc',
#  'nanog_classifier',
#  'Sox17_classifier',
#  'NKX25_classifier',
#  'TroponinT_classifier']
